# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
gau = [0.00 , 47.81 , -8.69]
cp2k = [0.00 , 36.48 , -42.02]

# %%
plt.figure(figsize=[12,6])
plt.plot(gau, ms=10, c='navy', marker='o', label="Gaussian09")
plt.plot(cp2k, ms=10, c='darkorange', marker='*', label="CP2K")
plt.xticks([0,1,2], ["R", "TS", "P"])
plt.legend()
plt.grid()
plt.title("Diels Alder Reaction")
plt.savefig("energy_profile.png")
